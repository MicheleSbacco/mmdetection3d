# %% [markdown]
# # Inferencer study

# %% [markdown]
# ### Various steps
# 1. Import and initialize the inferencer
# 2. Select some images, then **Just inference**
# 3. **Inference + Visualization**
# 4. **Remote** Inference + **Remote** Visualization

# %%
import sys

# # Print the PYTHONPATH before the modifications
# for i, path in enumerate(sys.path):
#     print(i, path)
# print()

# Add the new paths separately
# new_path1 = "/home/michele/.local/lib/python3.10/site-packages/"
# if not new_path1 in sys.path:
#     sys.path.insert(1, new_path1)
new_path2 = "/home/michele/code/michele_mmdet3d/"
if not new_path2 in sys.path:
    sys.path.insert(1, new_path2)

# # Print the PYTHONPATH after the modifications
# for i, path in enumerate(sys.path):
#     print(i, path)
# print()

# Print the version of MMCV
import mmcv
print(mmcv.__version__)
print(mmcv.__file__)
# Out:
# 2.1.0
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py

# %%
from mmdet3d.apis import LidarDet3DInferencer

# %%
#################################################################################################################
#                                           Initialize Inferencer                                               #
#################################################################################################################



# # HARD P.P.
# # Initialize the actual inferencer class
# inferencer = LidarDet3DInferencer(model='/home/michele/code/Presentation_results/PPillars_Checkpoints/PPillars_HardVox/CONDENSED-HARD_pointpillars_minerva.py', 
#                                   weights='/home/michele/code/Presentation_results/PPillars_Checkpoints/PPillars_HardVox/Checkpoints/epoch_61.pth',
#                                   show_progress=False)

# CONE-AUGMENTED HARD P.P.
# Initialize the actual inferencer class
inferencer = LidarDet3DInferencer(model='/home/michele/code/Presentation_results/PPillars_Checkpoints/Cone-Augmented_HardVox/CONE-AUGMENTED-HARD_pointpillars_minerva.py', 
                                  weights='/home/michele/code/Presentation_results/PPillars_Checkpoints/Cone-Augmented_HardVox/Checkpoints/epoch_55.pth',
                                  show_progress=False)

# # DYNAMIC BIG_DATASET
# # Initialize the actual inferencer class
# inferencer = LidarDet3DInferencer(model='/home/michele/code/michele_mmdet3d/configs/minerva/CONDENSED-DYNAMIC_pointpillars_minerva.py', 
#                                   weights='/home/michele/code/michele_mmdet3d/data/minerva_polimove/Training_BigVoxels_BigDataset_Dynamic/Checkpoints_BigVoxels_BigDataset_Dynamic/epoch_61_BigVoxels_BigDataset_Dynamic.pth',
#                                   show_progress=False)

# # CONE-SHAPED
# # Initialize the actual inferencer class
# inferencer = LidarDet3DInferencer(model='/home/michele/code/michele_mmdet3d/configs/minerva/CONE-SHAPED-DYNAMIC_pointpillars_minerva.py', 
#                                   weights='/home/michele/code/michele_mmdet3d/work_dirs/pointpillars_minerva/epoch_49.pth',
#                                   show_progress=False)
# Out:
# /home/michele/code/michele_mmdet3d/mmdet3d/models/dense_heads/anchor3d_head.py:94: UserWarning: dir_offset and dir_limit_offset will be depressed and be incorporated into box coder in the future
#   warnings.warn(
# Loads checkpoint by local backend from path: /home/michele/code/Presentation_results/PPillars_Checkpoints/Cone-Augmented_HardVox/Checkpoints/epoch_55.pth
# 04/02 18:22:22 - mmengine - WARNING - Failed to search registry with scope "mmdet3d" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet3d" is a correct scope, or whether the registry is initialized.
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# /usr/local/lib/python3.10/dist-packages/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '

# %%
#################################################################################################################
#                                               Just Inference                                                  #
#################################################################################################################



# Dynamic reading of the file root_path
import os
root_path = inferencer.cfg.val_dataloader.dataset.data_root

# Read the files in validation list
val_list_txt_file = os.path.join("/home/michele/code/michele_mmdet3d", root_path, "ImageSets/val.txt")
with open(val_list_txt_file, 'r') as file:
    val_file_names = [line.strip() for line in file]

# Choose a smaller set of the validation files
one_every_n = 1
max_number = 1e3
wait_time_default = 15
inputs = []
for i, name in enumerate(val_file_names):
    if i%one_every_n==0 and len(inputs)<max_number:
        inputs.append(dict(points=("/home/michele/code/michele_mmdet3d/" + root_path + "training/velodyne/"+name+".bin")))

print(f"Total validation point_clouds: {len(val_file_names)}")
print(f"\tOne every n: {one_every_n}")
print(f"\tMax number: {max_number}")
print(f"\tSelected point_clouds: {len(inputs)}")

# Initial format for the inputs was the following:
results = []
for input in inputs:
    results.append(inferencer(input))
# Out:
# Total validation point_clouds: 266
# 	One every n: 1
# 	Max number: 1000.0
# 	Selected point_clouds: 266
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
selected_range = [85, 95]
corresponding_indices = []

for i, element in enumerate(results):
    if len(element['predictions'][0]['bboxes_3d'])>0:
        if element['predictions'][0]['bboxes_3d'][0][0] > selected_range[0] \
        and \
        element['predictions'][0]['bboxes_3d'][0][0] < selected_range[1] \
        and \
        element['predictions'][0]['bboxes_3d'][0][1] > 0:
            corresponding_indices.append(i)
            print(element['predictions'][0]['lidar_path'])
# Out:
# /home/michele/code/michele_mmdet3d/data/minerva_polimove_cones_augmented/training/velodyne/1722779815663998632.bin
# /home/michele/code/michele_mmdet3d/data/minerva_polimove_cones_augmented/training/velodyne/1722779822714816189.bin
# /home/michele/code/michele_mmdet3d/data/minerva_polimove_cones_augmented/training/velodyne/1724008118416583871.bin
# /home/michele/code/michele_mmdet3d/data/minerva_polimove_cones_augmented/training/velodyne/1724008135209263921.bin
# /home/michele/code/michele_mmdet3d/data/minerva_polimove_cones_augmented/training/velodyne/1724014498762141464.bin
# /home/michele/code/michele_mmdet3d/data/minerva_polimove_cones_augmented/training/velodyne/1724014498815106504.bin
# /home/michele/code/michele_mmdet3d/data/minerva_polimove_cones_augmented/training/velodyne/1724014510814764495.bin
# /home/michele/code/michele_mmdet3d/data/minerva_polimove_cones_augmented/training/velodyne/1724014511969563488.bin
# /home/michele/code/michele_mmdet3d/data/minerva_polimove_cones_augmented/training/velodyne/1724014658824789595.bin

# %%
#################################################################################################################
#                                           Inference and Visualize                                             #
#################################################################################################################

corresponding_indices = [corresponding_indices[2], corresponding_indices[3]]

# NOTE by Michele:  The visualization does not work properly if it gets passed a list. So just cycle through the 
#       "__call__" funcion of the inferencer
for i, input in enumerate(inputs):
    if i in corresponding_indices:
        inferencer(input, show=True, wait_time = 45)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 5
#       1 #################################################################################################################
#       2 #                                           Inference and Visualize                                             #
#       3 #################################################################################################################
# ----> 5 corresponding_indices = [corresponding_indices[2], corresponding_indices[3]]
#       7 # NOTE by Michele:  The visualization does not work properly if it gets passed a list. So just cycle through the
#       8 #       "__call__" funcion of the inferencer
#       9 for i, input in enumerate(inputs):
#
# IndexError: list index out of range

# %%
#################################################################################################################
#                                              Remote Inferencer                                                #
#################################################################################################################



import shutil
out_directory = '/home/michele/code/michele_mmdet3d/data/minerva_polimove/remote_inference/'
if os.path.exists(out_directory):
    shutil.rmtree(out_directory)
    print("Pre-existing directory removed. Will be created again from scratch")

# NOTE by Michele:  Same as above (need to use the for loop)
for input in inputs:
    inferencer(input, show=False, out_dir=out_directory)

# Visualize the predictions from the saved files
local_inferencer = LidarDet3DInferencer(model='/home/michele/code/michele_mmdet3d/configs/minerva/CONDENSED_pointpillars_minerva.py',
                                        weights='/home/michele/code/michele_mmdet3d/work_dirs/pointpillars_minerva/epoch_120.pth')

saved_predictions = [(out_directory + "preds/" + filename) for filename in os.listdir(out_directory + "preds/")]
local_inferencer.visualize_preds_fromfile(saved_predictions, show=True, wait_time = wait_time_default)
# Out:
# 	Visualizing file with timestamp:	1722779438018410534
# 	Visualizing file with timestamp:	1722779441920098607
# 	Visualizing file with timestamp:	1722779442063809464
# 	Visualizing file with timestamp:	1722779543217055232
# 	Visualizing file with timestamp:	1722779549463129007
# 	Visualizing file with timestamp:	1722779549765983279
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722779549864099679
# 	Visualizing file with timestamp:	1722779550864889786
# 	Visualizing file with timestamp:	1722779558612653598
# 	Visualizing file with timestamp:	1722779594265712606
# 	Visualizing file with timestamp:	1722779601213811882
# 	Visualizing file with timestamp:	1722779603318671052
# 	Visualizing file with timestamp:	1722779607216882378
# 	Visualizing file with timestamp:	1722779617616329609
# 	Visualizing file with timestamp:	1722779618120287930
# 	Visualizing file with timestamp:	1722779667516623560
# 	Visualizing file with timestamp:	1722779671316995803
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722779672418486960
# 	Visualizing file with timestamp:	1722779679065743485
# 	Visualizing file with timestamp:	1722779681918673323
# 	Visualizing file with timestamp:	1722779692767478447
# 	Visualizing file with timestamp:	1722779755563760969
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722779759123082909
# 	Visualizing file with timestamp:	1722779760661832787
# 	Visualizing file with timestamp:	1722779763266190323
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722779763565336130
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722779763761497054
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722779764264408163
# 	Visualizing file with timestamp:	1722779805615930220
# 	Visualizing file with timestamp:	1722779812911408715
# 	Visualizing file with timestamp:	1722779815663998632
# 	Visualizing file with timestamp:	1722779822714816189
# 	Visualizing file with timestamp:	1722779835313183081
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722779835464917801
# 	Visualizing file with timestamp:	1722779841713715154
# 	Visualizing file with timestamp:	1722779843913470377
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722779859064296391
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722779863567624797
# 	Visualizing file with timestamp:	1722779864319541410
# 	Visualizing file with timestamp:	1722779865067678289
# 	Visualizing file with timestamp:	1722779886770831049
# 	Visualizing file with timestamp:	1722779887664927009
# 	Visualizing file with timestamp:	1722779889616598361
# 	Visualizing file with timestamp:	1722779893213945103
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722779896113297974
# 	Visualizing file with timestamp:	1722779896271292811
# 	Visualizing file with timestamp:	1722779897216428217
# 	Visualizing file with timestamp:	1722779897967792095
# 	Visualizing file with timestamp:	1722779898762262208
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722779899764688458
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722779900266945820
# 	Visualizing file with timestamp:	1722779900316817127
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722779980416046642
# 	Visualizing file with timestamp:	1722780030768526123
# 	Visualizing file with timestamp:	1722780034412597796
# 	Visualizing file with timestamp:	1722780036960776608
# 	Visualizing file with timestamp:	1722780037214166471
# 	Visualizing file with timestamp:	1722780039167580961
# 	Visualizing file with timestamp:	1722780042314922525
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722780053172873517
# 	Visualizing file with timestamp:	1722780057260380584
# 	Visualizing file with timestamp:	1722780058015935388
# 	Visualizing file with timestamp:	1722780062720822186
# 	Visualizing file with timestamp:	1722780068915297256
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722780069378381062
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722780069863335171
# 	Visualizing file with timestamp:	1722780077913833268
# 	Visualizing file with timestamp:	1722780083366931563
# 	Visualizing file with timestamp:	1722780086718227365
# 	Visualizing file with timestamp:	1722780092016074140
# 	Visualizing file with timestamp:	1722780100768941524
# 	Visualizing file with timestamp:	1722780101413160672
# 	Visualizing file with timestamp:	1722780103914649485
# 	Visualizing file with timestamp:	1722780104614364542
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722780107514243740
# 	Visualizing file with timestamp:	1722780107868596903
# 	Visualizing file with timestamp:	1722780110472413055
# 	Visualizing file with timestamp:	1722780225813077265
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1722780227363820285
# 	Visualizing file with timestamp:	1722780227965117285
# 	Visualizing file with timestamp:	1722780230414564573
# 	Visualizing file with timestamp:	1723055055112982603
# 	Visualizing file with timestamp:	1723055071909567053
# 	Visualizing file with timestamp:	1723055072510713114
# 	Visualizing file with timestamp:	1723055075010382849
# 	Visualizing file with timestamp:	1723055075610655836
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1723055076414417069
# 	Visualizing file with timestamp:	1723055077165520521
# 	Visualizing file with timestamp:	1723055078610237744
# 	Visualizing file with timestamp:	1723055078959594555
# 	Visualizing file with timestamp:	1723055079211301709
# 	Visualizing file with timestamp:	1723055082459204304
# 	Visualizing file with timestamp:	1723055097460625447
# 	Visualizing file with timestamp:	1723055106765671641
# [Open3D WARNING] invalid color in PaintUniformColor, clipping to [0, 1]
# 	Visualizing file with timestamp:	1723055117060610068
# 	Visualizing file with timestamp:	1723055121660472676
# 	Visualizing file with timestamp:	1723055121871032268
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 15
#      13 # NOTE by Michele:  Same as above (need to use the for loop)
#      14 for input in inputs:
# ---> 15     inferencer(input, show=False, out_dir=out_directory)
#      17 # Visualize the predictions from the saved files
#      18 local_inferencer = LidarDet3DInferencer(model='/home/michele/code/michele_mmdet3d/configs/minerva/CONDENSED_pointpillars_minerva.py',
#      19                                         weights='/home/michele/code/michele_mmdet3d/work_dirs/pointpillars_minerva/epoch_120.pth')
#
# File /home/michele/code/michele_mmdet3d/mmdet3d/apis/inferencers/lidar_det3d_inferencer.py:314, in LidarDet3DInferencer.__call__(self, inputs, batch_size, return_datasamples, gt_bboxes, **kwargs)
#     311     # Return the losses in the form of a Python list
#     312     return [float(losses['loss_cls'][0]), float(losses['loss_bbox'][0]), float(losses['loss_dir'][0])]
# --> 314 visualization = self.visualize(ori_inputs, preds,
#     315                                **visualize_kwargs)
#     316 results = self.postprocess(preds, visualization,
#     317                            return_datasamples,
#     318                            **postprocess_kwargs)
#     319 results_dict['predictions'].extend(results['predictions'])
#
# File /home/michele/code/michele_mmdet3d/mmdet3d/apis/inferencers/lidar_det3d_inferencer.py:204, in LidarDet3DInferencer.visualize(self, inputs, preds, return_vis, show, wait_time, draw_pred, pred_score_thr, no_save_vis, img_out_dir)
#     201     o3d_save_path = None
#     203 data_input = dict(points=points)
# --> 204 self.visualizer.add_datasample(
#     205     pc_name,
#     206     data_input,
#     207     pred,
#     208     show=show,
#     209     wait_time=wait_time,
#     210     draw_gt=False,
#     211     draw_pred=draw_pred,
#     212     pred_score_thr=pred_score_thr,
#     213     o3d_save_path=o3d_save_path,
#     214     vis_task='lidar_det',
#     215 )
#     216 results.append(points)
#     217 self.num_visualized_frames += 1
#
# File /usr/local/lib/python3.10/dist-packages/mmengine/dist/utils.py:427, in master_only.<locals>.wrapper(*args, **kwargs)
#     424 @functools.wraps(func)
#     425 def wrapper(*args, **kwargs):
#     426     if is_main_process():
# --> 427         return func(*args, **kwargs)
#
# File /home/michele/code/michele_mmdet3d/mmdet3d/visualization/local_visualizer.py:1102, in Det3DLocalVisualizer.add_datasample(self, name, data_input, data_sample, draw_gt, draw_pred, show, wait_time, out_file, o3d_save_path, vis_task, pred_score_thr, step, show_pcd_rgb)
#    1098     # .cpu can not be used for BaseInstance3DBoxes
#    1099     # so we need to use .to('cpu')
#    1100     pred_instances_3d = pred_instances_3d[
#    1101         pred_instances_3d.scores_3d > pred_score_thr].to('cpu')
# -> 1102     pred_data_3d = self._draw_instances_3d(data_input,
#    1103                                            pred_instances_3d,
#    1104                                            data_sample.metainfo,
#    1105                                            vis_task, show_pcd_rgb,
#    1106                                            palette)
#    1107 if 'pred_instances' in data_sample:
#    1108     if 'img' in data_input and len(data_sample.pred_instances) > 0:
#
# File /home/michele/code/michele_mmdet3d/mmdet3d/visualization/local_visualizer.py:687, in Det3DLocalVisualizer._draw_instances_3d(self, data_input, instances, input_meta, vis_task, show_pcd_rgb, palette)
#     684 bbox_palette = get_palette(bbox_color, max_label + 1)
#     685 colors = [bbox_palette[label] for label in labels_3d]
# --> 687 self.set_points(
#     688     points, pcd_mode=2, mode='xyzrgb' if show_pcd_rgb else 'xyz')
#     689 self.draw_bboxes_3d(bboxes_3d_depth, bbox_color=colors)
#     691 data_3d['bboxes_3d'] = tensor2ndarray(bboxes_3d_depth.tensor)
#
# File /usr/local/lib/python3.10/dist-packages/mmengine/dist/utils.py:427, in master_only.<locals>.wrapper(*args, **kwargs)
#     424 @functools.wraps(func)
#     425 def wrapper(*args, **kwargs):
#     426     if is_main_process():
# --> 427         return func(*args, **kwargs)
#
# File /home/michele/code/michele_mmdet3d/mmdet3d/visualization/local_visualizer.py:257, in Det3DLocalVisualizer.set_points(self, points, pcd_mode, vis_mode, frame_cfg, points_color, points_size, mode)
#     255 pcd = geometry.PointCloud()
#     256 if mode == 'xyz':
# --> 257     pcd.points = o3d.utility.Vector3dVector(points[:, :3])
#     258     points_colors = np.tile(
#     259         np.array(points_color), (points.shape[0], 1))
#     260 elif mode == 'xyzrgb':
#
# KeyboardInterrupt:

# %% [markdown]
# # VoxelNet(SingleStage3DDetector(Base3DDetector)): Description by ChatGPT

# %% [markdown]
# The `Base3DDetector` class in MMDetection3D serves as a parent class for 3D detectors, providing a unified interface for 3D object detection models. It inherits from `BaseDetector`, which is part of the 2D detection framework MMDetection, and extends it to handle 3D-specific data and operations. Below, I'll break down its interactions with PyTorch and explain its overall workflow:
#
# ### 1. **Interaction with PyTorch**
# The main interactions with PyTorch happen in the `forward` method, which handles different modes of operation: `'tensor'`, `'predict'`, and `'loss'`. These modes control how the model processes inputs and interacts with PyTorch tensors.
#
# 1. **Forward Pass (`mode='tensor'`)**:
#    When `mode='tensor'`, the `forward()` method calls `_forward()`. This is where the network processes the inputs through the various layers defined in the specific detector model (e.g., backbone, neck, head). This is a typical PyTorch `nn.Module` forward pass, which returns raw tensor outputs directly without additional processing.
#
# 2. **Prediction (`mode='predict'`)**:
#    When `mode='predict'`, it processes the inputs and data samples using the `predict()` method. This involves running inference, post-processing, and formatting the results into structured outputs like bounding boxes, scores, and labels. During this stage, PyTorch is used for operations like applying non-maximum suppression (NMS) on 3D bounding boxes and converting model outputs into usable predictions.
#
# 3. **Loss Calculation (`mode='loss'`)**:
#    When `mode='loss'`, it calculates and returns the loss values using the `loss()` method. This mode is used during training. The `inputs` and `data_samples` are passed to the `loss()` function, which computes various losses (e.g., classification, regression) based on ground truth data. The resulting tensors are then used by the optimizer for backpropagation in a typical PyTorch training loop.
#
# ### 2. **High-Level Workflow of `Base3DDetector`**
# The overall workflow of the class, when instantiated as part of a detector model, follows these steps:
#
# 1. **Initialization (`__init__` method)**:
#    - The class accepts a `data_preprocessor` and an `init_cfg` argument.
#    - `data_preprocessor` configures preprocessing steps like padding, mean normalization, and standardization for both point cloud and image data.
#    - `init_cfg` handles initialization settings, such as loading pretrained weights or defining weight initialization schemes.
#
# 2. **Forward Method (`forward`)**:
#    The `forward()` method is the unified entry point for different operations. It accepts the following key parameters:
#    - `inputs`: A dictionary or list of dictionaries containing batch data. It typically includes keys like `points` (for point cloud data) and `imgs` (for image data).
#    - `data_samples`: Optional annotation data for each sample, such as ground truth 3D bounding boxes.
#    - `mode`: The mode to run the forward process (`'tensor'`, `'predict'`, or `'loss'`).
#
#    Based on the mode, it delegates the call to one of three methods:
#    - **`loss()`**: Computes the loss for training.
#    - **`predict()`**: Processes inputs and generates predictions.
#    - **`_forward()`**: Returns the raw tensor outputs for deeper analysis or debugging.
#
# 3. **Adding Predictions to Data Samples (`add_pred_to_datasample` method)**:
#    This utility method formats the model outputs into the structure required for downstream use. It converts raw predictions into the `Det3DDataSample` format, which includes keys like:
#    - `pred_instances_3d`: Contains 3D bounding boxes (`bboxes_3d`), labels (`labels_3d`), and scores (`scores_3d`).
#    - `pred_instances`: Similar structure for 2D bounding boxes if applicable.
#
#    It creates new `InstanceData` objects for missing 3D or 2D data and adds these predictions back into the `data_samples` list. This structure makes it easier to evaluate and visualize the results later.
#
# ### 3. **Usage in PyTorch Training and Inference Loops**
# The `Base3DDetector` class is designed to fit seamlessly into PyTorch's training and inference workflows. During training, it is used as follows:
#
# 1. **Training**:
#    - When calling `model(inputs, data_samples, mode='loss')`, the class processes the input data through the network and computes the loss.
#    - The loss dictionary is used by the optimizer to perform backpropagation and update weights.
#
# 2. **Inference**:
#    - When calling `model(inputs, data_samples, mode='predict')`, it produces the post-processed predictions in the format expected by MMDetection3D's evaluation pipeline.
#    - Predictions are wrapped into `Det3DDataSample` objects, making it easy to evaluate using standard metrics (e.g., mAP, AP40).
#
# 3. **Debugging and Tensor Operations**:
#    - When calling `model(inputs, mode='tensor')`, it skips all post-processing and returns the raw tensors directly, allowing for deeper debugging or custom analysis using PyTorch tensor operations.
#
# ### 4. **Extensibility for New 3D Detection Models**
# The `Base3DDetector` class serves as a template for implementing new 3D detectors. Derived classes can:
# - Override `loss()` to implement custom loss functions.
# - Implement `predict()` for different types of 3D detectors (e.g., voxel-based, point-based).
# - Customize `_forward()` to define different network architectures.
#
# ### 5. **Example: How it Fits in an MMDetection3D Pipeline**
# Consider a typical 3D object detection training pipeline:
# 1. **Data Preprocessing**: The dataset class formats input point clouds and images, passes them through the preprocessor, and provides `inputs` and `data_samples`.
# 2. **Training Loop**: The model’s `forward()` method is called in `'loss'` mode, computing the losses.
# 3. **Inference Loop**: During testing, the same `forward()` method is called in `'predict'` mode to generate detection results.
# 4. **Result Formatting**: `add_pred_to_datasample()` structures the output for easy evaluation and visualization.
#
# In essence, `Base3DDetector` provides the foundation, and specific 3D detectors extend it to implement unique architectures and functionality tailored to their tasks.

# %% [markdown]
# # Model analysis

# %% [markdown]
# ### **Components of the model inside MMDetection3D:** --------------------------------------------------------------------------------------------------------------------------------------------------------
# - General type of net is "VoxelNet" with the following sub-components:
#     1. data_preprocessor
#     2. voxel_encoder
#     3. middle_encoder
#     4. backbone
#     5. neck
#     6. bbox_head
# - Better description of the "3DDetector" class in the paragraph above

# %% [markdown]
# ### **Data Preprocessor (Det3DDataPreprocessor)** ------------------------------------------------------------------------------------------------------------------------------------------------------------
# - By delving into *VoxelNet --> SingleStage3DDetector --> Base3DDetector --> BaseDetector --> BaseModel*, you can find that the **data_preprocessor** is called every time the *"run_forward"* method is called.
#     - *"run_forward"* can be of **mode=predict** in *"val_step"* and *"test_step"*, or it can be of **mode=loss** in *"train_step"*
#     - The data_preprocessor provides the basic data for the *"run_forward"* method to be executed
# - In our case the data_preprocessor is of class **"Det3DDataPreprocessor"**.
#     - Calls the function *"voxelize"* that can be of four types: hard/dynamic/cylindrical/minkunet voxelization. In our case it is **hard** voxelization.
#     - Performs the voxelization based on the information provided to the dictionary **"voxel_layer"** in the configuration file.
#         - max_voxels
#         - max_num_points
#         - point_cloud_range
#         - voxel_size
# - The voxelization_layer is of **class VoxelizationByGridShape** which also accepts the flag *"deterministic = False"* which may speed up the process. <mark>It is worth a try</mark>
# - There is a way to perform **dynamic voxelization**, and also a VoxelEncoder that supports dynamic voxelization (same file as the other). <mark>It is worth a try</mark>

# %% [markdown]
# ### **Voxel Encoder (PillarFeatureNet)** ---------------------------------------------------------------------------------------------------------------------------------------------------------------------
# - Performs the first processing of the voxels.
#     - Takes as input a tensor of shape (NxMxC) with N=n. of pillars, M=n. of max points per pillar, C=n. of features per point (in our case 4).
#     - To the input some parameters can be added, such as *cluster center distance* (from centroid), *voxel center distance* (from voxel centre), and *distance from the origin* (from voxel origin). So the new input becomes (NxMxC_augmented). This method is called **feature augmentation**.
#     - For each pillar, **pooling** is performed (either max or average) to extract the main features of the pillar. The number of features is defined in the parameter **"feat_channels"**. <mark>May try to modify **number of features** and also **type of pooling**</mark>
#     - The output is (NxC_features) where C_features is exactly the parameter *"feat_channels"*.

# %% [markdown]
# ### **Middle Encoder (PointPillarsScatter)** -----------------------------------------------------------------------------------------------------------------------------------------------------------------
# - Simply takes the voxels as listed in a **(NxC_features)** tensor, and turns them into a **(1xC_featuresxN_yxN_x)** tensor.
# - Essentially, takes the pillars **from a 1-D representation** and orders them **to a grid-like structure** which can be used **for CNN-like computations**.

# %% [markdown]
# ### **Backbone (SECOND)** ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# - Convolution in 3 steps as explained in the following.
#     - From (C, X, Y)        to      (C, X/2, Y/2)
#     - From (C, X/2, Y/2)    to      (2C, X/4, Y/4)
#     - From (2C, X/4, Y/4)   to      (4C, X/8, Y/8)
# - All of these layers proceed in **PARALLEL**, and they will be decovoluted and then concatenated in the neck (see below)

# %% [markdown]
# ### **Neck (SECOND FPN)** ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# - Another standard FPN: Feature Pyramid Network.
#     - There are a down-sampling and then up-sampling that proceed in parallel with **lateral connections** that are then merged together.
#     - Multi-scale features allow to get spacial resolution from non-scaled images, and feature richness by scaled images.
# - The up-sampling works like the following.
#     - From (C, X/2, Y/2)    to      (2C, X/2, Y/2)
#     - From (2C, X/4, Y/4)   to      (2C, X/2, Y/2)
#     - From (4C, X/8, Y/8)   to      (2C, X/2, Y/2)
# - So at the end there are 2C-thick layers for three times, and they are sticked together to get (6C, X/2, Y/2).

# %% [markdown]
# ### **BBox Head (Anchor3DHead)** -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# - Takes as input the feature map, and outputs the final results for prediction and training.
#     - For just **INFERENCE** the outputs are
#         - Predicted BBox parameters (7 values).
#         - Classification scores for each BBox, a value for each class.
#         - Direction classification.
#     - For **TRAINING** the outputs are instead
#         - Classification scores, BBox offset from center, classification predictions.
#         - Loss values for the back-propagation, so *loss_cls/loss_bbox/loss_dir*.
